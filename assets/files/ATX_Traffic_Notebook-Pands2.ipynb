# %%
# !pwd
# Out:
# /content

# %%
# !cd /content/drive/MyDrive/sgx3-codinginstitute-25

# %%
# !pwd
# Out:
# /content

# %%
# !more ATX-Traffic.csv
# Out:
# Traffic Report ID,Published Date,Issue Reported,Location,Latitude,Longitude,Addr
# ess,Status,Status Date,Agency
# F350D780EA8AAA48030B4DB64F790C14DBCD757F_1709688579,03/06/2024 01:29:39 AM +0000
# ,Stalled Vehicle,POINT (-97.705874 30.32358),30.32358,-97.705874,E 290 Svrd Wb T
# o Ih 35 Nb Ramp / N Ih 35 Svrd Sb At E 290 Tr,ARCHIVED,03/06/2024 02:10:12 AM +0
# 000,AUSTIN PD
# 042338D46C2028808F298DEC735DC7ADF0C162F6_1709688402,03/06/2024 01:26:42 AM +0000
# ,Crash Urgent,POINT (-97.698567 30.342505),30.342505,-97.698567,8024 N Ih 35 Svr
# d Sb,ARCHIVED,03/06/2024 02:45:13 AM +0000,AUSTIN PD
# BE73E73B642ECB6C6EDB4A52875A8017F69DFE5E_1708035468,02/15/2024 10:17:48 PM +0000
# ,LOOSE LIVESTOCK,POINT (-97.717911 30.0578),30.0578,-97.717911,12400 Glass Rd,AR
# CHIVED,02/15/2024 11:33:08 PM +0000,TRAVIS COUNTY SHERIF
# A5909010064EF753C5F090A07CFCDDFBF25E38F3_1586554271,04/10/2020 09:31:11 PM +0000
# ,TRFC HAZD/ DEBRIS,POINT (-97.866676 30.140878),30.140878,-97.866676,S Sh 45 W E
# b & S Sh 45 W Eb To Bliss Spillar Ramp,ARCHIVED,04/10/2020 09:55:03 PM +0000,
# 4A6C39763AD109EB75CE31C1EBFD53A0E883EE68_1654365065,06/04/2022 05:51:05 PM +0000
# ,Traffic Hazard,POINT (-97.825791 30.455444),30.455444,-97.825791,Anderson Mill
# Rd & N Fm 620 Rd,ARCHIVED,06/04/2022 06:20:03 PM +0000,
# 388082EEB5EE93B2E562236F9D37CD0B5D74F08E_1709688918,03/06/2024 01:35:18 AM +0000
# ,COLLISION,POINT (-97.823787 30.139435),30.139435,-97.823787,665 W FM 1626 TO ST
# ATION,ARCHIVED,03/06/2024 02:35:11 AM +0000,TRAVIS COUNTY SHERIF
# 09203A0B810D0C054F3F15D6DB42AA850BEA9174_1709681646,03/05/2024 11:34:06 PM +0000
# ,Crash Urgent,POINT (-97.810932 30.475283),30.475283,-97.810932,2787 S Lakeline
# Blvd,ARCHIVED,03/06/2024 12:25:11 AM +0000,AUSTIN PD
# 0864A91883AB86909614F36A588EE81376A25C45_1709682781,03/05/2024 11:53:01 PM +0000
# ,COLLISION,POINT (-97.666111 30.453168),30.453168,-97.666111,15700 N Ih 35 Nb,AR
# CHIVED,03/06/2024 12:30:12 AM +0000,TRAVIS COUNTY SHERIF

# %%
import pandas as pd

# %%
#load the dataset
df = pd.read_csv("/content/ATX-Traffic.csv")
# Out:
# <ipython-input-11-713477764>:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/ATX-Traffic.csv")

# %%
# Preview
df.head()
# Out:
#                                    Traffic Report ID  \
# 0  F350D780EA8AAA48030B4DB64F790C14DBCD757F_17096...
# 1  042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 2  BE73E73B642ECB6C6EDB4A52875A8017F69DFE5E_17080...
# 3  A5909010064EF753C5F090A07CFCDDFBF25E38F3_15865...
# 4  4A6C39763AD109EB75CE31C1EBFD53A0E883EE68_16543...
#
#                  Published Date     Issue Reported  \
# 0  03/06/2024 01:29:39 AM +0000    Stalled Vehicle
# 1  03/06/2024 01:26:42 AM +0000       Crash Urgent
# 2  02/15/2024 10:17:48 PM +0000    LOOSE LIVESTOCK
# 3  04/10/2020 09:31:11 PM +0000  TRFC HAZD/ DEBRIS
# 4  06/04/2022 05:51:05 PM +0000     Traffic Hazard
#
#                        Location   Latitude  Longitude  \
# 0   POINT (-97.705874 30.32358)  30.323580 -97.705874
# 1  POINT (-97.698567 30.342505)  30.342505 -97.698567
# 2    POINT (-97.717911 30.0578)  30.057800 -97.717911
# 3  POINT (-97.866676 30.140878)  30.140878 -97.866676
# 4  POINT (-97.825791 30.455444)  30.455444 -97.825791
#
#                                              Address    Status  \
# 0  E 290 Svrd Wb To Ih 35 Nb Ramp / N Ih 35 Svrd ...  ARCHIVED
# 1                               8024 N Ih 35 Svrd Sb  ARCHIVED
# 2                                     12400 Glass Rd  ARCHIVED
# 3  S Sh 45 W Eb & S Sh 45 W Eb To Bliss Spillar Ramp  ARCHIVED
# 4                     Anderson Mill Rd & N Fm 620 Rd  ARCHIVED
#
#                     Status Date                Agency
# 0  03/06/2024 02:10:12 AM +0000  AUSTIN PD
# 1  03/06/2024 02:45:13 AM +0000  AUSTIN PD
# 2  02/15/2024 11:33:08 PM +0000  TRAVIS COUNTY SHERIF
# 3  04/10/2020 09:55:03 PM +0000                   NaN
# 4  06/04/2022 06:20:03 PM +0000                   NaN

# %%
df.shape
# Out:
# (425641, 10)

# %%
df.columns
# Out:
# Index(['Traffic Report ID', 'Published Date', 'Issue Reported', 'Location',
#        'Latitude', 'Longitude', 'Address', 'Status', 'Status Date', 'Agency'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425641 entries, 0 to 425640
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Traffic Report ID  425641 non-null  object
#  1   Published Date     425641 non-null  object
#  2   Issue Reported     425641 non-null  object
#  3   Location           425376 non-null  object
#  4   Latitude           425562 non-null  float64
#  5   Longitude          425562 non-null  float64
#  6   Address            425641 non-null  object
#  7   Status             423948 non-null  object
#  8   Status Date        425641 non-null  object
#  9   Agency             69057 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 32.5+ MB

# %%
df.describe()
# Out:
#            Latitude      Longitude
# count  4.255620e+05  425562.000000
# mean   5.701659e+03     -97.518368
# std    4.110550e+05       4.544944
# min    0.000000e+00     -98.816154
# 25%    3.023067e+01     -97.776078
# 50%    3.029459e+01     -97.731703
# 75%    3.037432e+01     -97.680807
# max    2.999603e+07       0.000000

# %%
unique_issues = df['Issue Reported'].unique()

# %%
print(unique_issues)
# Out:
# ['Stalled Vehicle' 'Crash Urgent' 'LOOSE LIVESTOCK' 'TRFC HAZD/ DEBRIS'
#  'Traffic Hazard' 'COLLISION' 'COLLISION/PRIVATE PROPERTY'
#  'FLEET ACC/ INJURY' 'Crash Service' 'COLLISION WITH INJURY'
#  'COLLISN/ LVNG SCN' 'zSTALLED VEHICLE' 'BOAT ACCIDENT' 'VEHICLE FIRE'
#  'BLOCKED DRIV/ HWY' 'TRAFFIC FATALITY' 'AUTO/ PED' 'Traffic Impediment'
#  'N / HZRD TRFC VIOL' 'ICY ROADWAY' 'COLLISN / FTSRA' 'FLEET ACC/ FATAL'
#  'OBSTRUCT HWY' 'HIGH WATER']

# %%
name = 'Charlie'

# %%
print (name)
# Out:
# Charlie

# %%
type(name)
# Out:
# str

# %%
type(unique_issues)
# Out:
# numpy.ndarray

# %%
print (unique_issues.size)
# Out:
# 24

# %%
df['Issue Reported'].nunique()
# Out:
# 24

# %%
df['Issue Reported'] == 'Crash Urgent'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 425636    False
# 425637    False
# 425638    False
# 425639    False
# 425640    False
# Name: Issue Reported, Length: 425641, dtype: bool

# %%
df[df['Issue Reported'] == 'Crash Urgent']
# Out:
#                                         Traffic Report ID  \
# 1       042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 6       09203A0B810D0C054F3F15D6DB42AA850BEA9174_17096...
# 12      9521E2BCC9C0DE945CCF68B52345097002B66BA5_17096...
# 14      E90E88C880E48E96024E634381BA1AD4888E72E0_17096...
# 17      7FCDB7BA6DE74B6E007EFE1079540E0228817D26_17096...
# ...                                                   ...
# 425608  823B29FFD8DBAB9367EDDCA53376226A17CDC00F_17496...
# 425611  88C79C1DC9D13B2B592B9057730DF504809A43C1_17496...
# 425615  F4F9DD8C2988666B84167D2D7E58D654A53560A1_17496...
# 425618  FFEEAE89101150B85AC054F8625E928F11D2FBB0_17496...
# 425628  72448B7792D7AA9BAE361029D06BB23AD7803155_17496...
#
#                       Published Date Issue Reported  \
# 1       03/06/2024 01:26:42 AM +0000   Crash Urgent
# 6       03/05/2024 11:34:06 PM +0000   Crash Urgent
# 12      03/06/2024 02:45:22 AM +0000   Crash Urgent
# 14      03/06/2024 02:04:19 AM +0000   Crash Urgent
# 17      03/06/2024 02:30:38 AM +0000   Crash Urgent
# ...                              ...            ...
# 425608  06/11/2025 04:44:58 AM +0000   Crash Urgent
# 425611  06/11/2025 05:27:10 AM +0000   Crash Urgent
# 425615  06/11/2025 08:23:02 AM +0000   Crash Urgent
# 425618  06/11/2025 07:50:06 AM +0000   Crash Urgent
# 425628  06/11/2025 01:24:16 PM +0000   Crash Urgent
#
#                             Location   Latitude  Longitude  \
# 1       POINT (-97.698567 30.342505)  30.342505 -97.698567
# 6       POINT (-97.810932 30.475283)  30.475283 -97.810932
# 12       POINT (-97.774813 30.20489)  30.204890 -97.774813
# 14      POINT (-97.760691 30.202818)  30.202818 -97.760691
# 17      POINT (-97.696568 30.346648)  30.346648 -97.696568
# ...                              ...        ...        ...
# 425608  POINT (-97.734361 30.191606)  30.191606 -97.734361
# 425611  POINT (-97.752785 30.288622)  30.288622 -97.752785
# 425615    POINT (-97.76064 30.20243)  30.202430 -97.760640
# 425618  POINT (-97.816338 30.185877)  30.185877 -97.816338
# 425628  POINT (-97.699553 30.430483)  30.430483 -97.699553
#
#                                 Address    Status  \
# 1                  8024 N Ih 35 Svrd Sb  ARCHIVED
# 6                  2787 S Lakeline Blvd  ARCHIVED
# 12       S Congress Ave / W Stassney Ln  ARCHIVED
# 14                      5200 S Ih 35 Sb  ARCHIVED
# 17                 8312 N IH 35 SVRD SB  ARCHIVED
# ...                                 ...       ...
# 425608  CHINA BERRY RD / BIRCH CREEK RD  ARCHIVED
# 425611           2400-2422 N Lamar Blvd  ARCHIVED
# 425615                  5001 S IH 35 NB  ARCHIVED
# 425618           Menchaca Rd / Davis Ln  ARCHIVED
# 425628    2500-3140 Scofield Ridge Pkwy  ARCHIVED
#
#                          Status Date                Agency
# 1       03/06/2024 02:45:13 AM +0000  AUSTIN PD
# 6       03/06/2024 12:25:11 AM +0000  AUSTIN PD
# 12      03/06/2024 03:25:10 AM +0000  AUSTIN PD
# 14      03/06/2024 02:15:11 AM +0000  AUSTIN PD
# 17      03/06/2024 05:10:12 AM +0000  AUSTIN PD
# ...                              ...                   ...
# 425608  06/11/2025 05:01:10 AM +0000  AUSTIN PD
# 425611  06/11/2025 06:40:15 AM +0000  AUSTIN PD
# 425615  06/11/2025 09:15:22 AM +0000  AUSTIN PD
# 425618  06/11/2025 10:20:13 AM +0000  AUSTIN PD
# 425628  06/11/2025 03:10:34 PM +0000  AUSTIN PD
#
# [103763 rows x 10 columns]

# %%
df['Address'].str.contains('IH 35', na=False)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 425636    False
# 425637    False
# 425638    False
# 425639    False
# 425640    False
# Name: Address, Length: 425641, dtype: bool

# %%
df[df['Address'].str.contains('IH 35', na=False)]
# Out:
#                                         Traffic Report ID  \
# 17      7FCDB7BA6DE74B6E007EFE1079540E0228817D26_17096...
# 45      B91F4502A07105CEBCE7E632807B55F7657F988D_17126...
# 77      58907516874AA70188525B2518FAF0E285FD821A_17104...
# 93      B7341ADE93B73941045D59D28699793EECDF673D_17104...
# 149     508DE84D9E60D0EA4F80173324A7A9CC95DBEDB3_17122...
# ...                                                   ...
# 425239  142B577AA1967D757715FA937CC10D50E5814A4A_17493...
# 425415  6DBB169C06C09B479392E3A636171E8714B46023_17494...
# 425571  7A1B52FD835B0BEBB79168905903AD903FDA01BF_17495...
# 425575  7161A2409087E392CF68559DDAC9F1B64B07510C_17495...
# 425615  F4F9DD8C2988666B84167D2D7E58D654A53560A1_17496...
#
#                       Published Date   Issue Reported  \
# 17      03/06/2024 02:30:38 AM +0000     Crash Urgent
# 45      04/09/2024 04:55:22 PM +0000    Crash Service
# 77      03/15/2024 12:38:40 AM +0000  Stalled Vehicle
# 93      03/15/2024 12:49:08 AM +0000        COLLISION
# 149     04/04/2024 09:57:57 PM +0000     Crash Urgent
# ...                              ...              ...
# 425239  06/08/2025 04:50:04 AM +0000        COLLISION
# 425415  06/09/2025 05:12:24 PM +0000     Crash Urgent
# 425571  06/10/2025 07:44:10 PM +0000    Crash Service
# 425575  06/10/2025 10:18:26 PM +0000    Crash Service
# 425615  06/11/2025 08:23:02 AM +0000     Crash Urgent
#
#                             Location   Latitude  Longitude  \
# 17      POINT (-97.696568 30.346648)  30.346648 -97.696568
# 45      POINT (-97.770881 30.190674)  30.190674 -97.770881
# 77      POINT (-97.674028 30.407178)  30.407178 -97.674028
# 93      POINT (-97.665671 30.453514)  30.453514 -97.665671
# 149     POINT (-97.719288 30.295057)  30.295057 -97.719288
# ...                              ...        ...        ...
# 425239  POINT (-97.670877 30.433672)  30.433672 -97.670877
# 425415  POINT (-97.745657 30.225966)  30.225966 -97.745657
# 425571  POINT (-97.673793 30.414425)  30.414425 -97.673793
# 425575  POINT (-97.789085 30.162182)  30.162182 -97.789085
# 425615    POINT (-97.76064 30.20243)  30.202430 -97.760640
#
#                                       Address    Status  \
# 17                       8312 N IH 35 SVRD SB  ARCHIVED
# 45      E WILLIAM CANNON DR / S IH 35 SVRD SB  ARCHIVED
# 77                12439-12537 N IH 35 SVRD NB  ARCHIVED
# 93                15700-15827 N IH 35 SVRD NB  ARCHIVED
# 149                3800 N IH 35 UPPER DECK NB  ARCHIVED
# ...                                       ...       ...
# 425239                  14310 N IH 35 SVRD SB  ARCHIVED
# 425415                   3100-3500 S IH 35 NB  ARCHIVED
# 425571                  13000 N IH 35 SVRD SB  ARCHIVED
# 425575                   9500 S IH 35 SVRD SB  ARCHIVED
# 425615                        5001 S IH 35 NB  ARCHIVED
#
#                          Status Date                Agency
# 17      03/06/2024 05:10:12 AM +0000  AUSTIN PD
# 45      04/09/2024 06:30:15 PM +0000  AUSTIN PD
# 77      03/15/2024 01:00:16 AM +0000  AUSTIN PD
# 93      03/15/2024 01:30:13 AM +0000  TRAVIS COUNTY SHERIF
# 149     04/04/2024 11:25:48 PM +0000  AUSTIN PD
# ...                              ...                   ...
# 425239  06/08/2025 05:15:15 AM +0000  TRAVIS COUNTY SHERIF
# 425415  06/09/2025 05:45:18 PM +0000  AUSTIN PD
# 425571  06/10/2025 09:55:13 PM +0000  AUSTIN PD
# 425575  06/10/2025 11:25:15 PM +0000  AUSTIN PD
# 425615  06/11/2025 09:15:22 AM +0000  AUSTIN PD
#
# [8386 rows x 10 columns]

# %%
df[(df['Issue Reported'] == 'Crash Urgent') & (df['Address'].str.contains('IH 35', na=False))]
# Out:
#                                         Traffic Report ID  \
# 17      7FCDB7BA6DE74B6E007EFE1079540E0228817D26_17096...
# 149     508DE84D9E60D0EA4F80173324A7A9CC95DBEDB3_17122...
# 213     5F5898E4726001663BA5A126B313B03B1AED3F07_17097...
# 215     EC10DB9185C9C58A004FA683DD21AFCD16CAD418_17109...
# 289     BA2E8AA59E4161EE5807078F7226C405FDE751A6_15609...
# ...                                                   ...
# 424561  BF106F603F5A1CA065CB9438FB4EAE247D89AEF3_17488...
# 424688  A02A2FE9596BF1F59BD4CA2ECA3885C814393F10_17489...
# 424734  9304739C29A855AF7DDB1CFC420CB7CF57726E00_17489...
# 425415  6DBB169C06C09B479392E3A636171E8714B46023_17494...
# 425615  F4F9DD8C2988666B84167D2D7E58D654A53560A1_17496...
#
#                       Published Date Issue Reported  \
# 17      03/06/2024 02:30:38 AM +0000   Crash Urgent
# 149     04/04/2024 09:57:57 PM +0000   Crash Urgent
# 213     03/06/2024 04:59:46 PM +0000   Crash Urgent
# 215     03/20/2024 02:29:08 PM +0000   Crash Urgent
# 289     06/19/2019 11:26:40 PM +0000   Crash Urgent
# ...                              ...            ...
# 424561  06/02/2025 01:16:11 AM +0000   Crash Urgent
# 424688  06/03/2025 08:00:08 PM +0000   Crash Urgent
# 424734  06/03/2025 11:04:56 PM +0000   Crash Urgent
# 425415  06/09/2025 05:12:24 PM +0000   Crash Urgent
# 425615  06/11/2025 08:23:02 AM +0000   Crash Urgent
#
#                             Location   Latitude  Longitude  \
# 17      POINT (-97.696568 30.346648)  30.346648 -97.696568
# 149     POINT (-97.719288 30.295057)  30.295057 -97.719288
# 213      POINT (-97.67169 30.423909)  30.423909 -97.671690
# 215     POINT (-97.753967 30.213333)  30.213333 -97.753967
# 289     POINT (-97.737007 30.256942)  30.256942 -97.737007
# ...                              ...        ...        ...
# 424561  POINT (-97.761526 30.201368)  30.201368 -97.761526
# 424688    POINT (-97.7002 30.338787)  30.338787 -97.700200
# 424734  POINT (-97.764564 30.198096)  30.198096 -97.764564
# 425415  POINT (-97.745657 30.225966)  30.225966 -97.745657
# 425615    POINT (-97.76064 30.20243)  30.202430 -97.760640
#
#                                Address    Status  \
# 17                8312 N IH 35 SVRD SB  ARCHIVED
# 149         3800 N IH 35 UPPER DECK NB  ARCHIVED
# 213                   13600 N IH 35 SB  ARCHIVED
# 215     S IH 35 SVRD SB / E ST ELMO RD  ARCHIVED
# 289                   31-61 N IH 35 NB  ARCHIVED
# ...                                ...       ...
# 424561                 5400 S IH 35 NB  ARCHIVED
# 424688            7400-7801 N IH 35 NB  ARCHIVED
# 424734                 5700 S IH 35 SB  ARCHIVED
# 425415            3100-3500 S IH 35 NB  ARCHIVED
# 425615                 5001 S IH 35 NB  ARCHIVED
#
#                          Status Date                Agency
# 17      03/06/2024 05:10:12 AM +0000  AUSTIN PD
# 149     04/04/2024 11:25:48 PM +0000  AUSTIN PD
# 213     03/06/2024 06:45:25 PM +0000  AUSTIN PD
# 215     03/20/2024 05:10:26 PM +0000  AUSTIN PD
# 289     06/20/2019 01:00:05 AM +0000                   NaN
# ...                              ...                   ...
# 424561  06/02/2025 02:15:15 AM +0000  AUSTIN PD
# 424688  06/03/2025 08:50:19 PM +0000  AUSTIN PD
# 424734  06/04/2025 12:10:16 AM +0000  AUSTIN PD
# 425415  06/09/2025 05:45:18 PM +0000  AUSTIN PD
# 425615  06/11/2025 09:15:22 AM +0000  AUSTIN PD
#
# [2572 rows x 10 columns]

# %%
df['year'] = df['Published Date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-1691691430> in <cell line: 0>()
# ----> 1 df['year'] = df['Published Date'].dt.year
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     641             return PeriodProperties(data, orig)
#     642
# --> 643         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df.dtypes
# Out:
# Traffic Report ID     object
# Published Date        object
# Issue Reported        object
# Location              object
# Latitude             float64
# Longitude            float64
# Address               object
# Status                object
# Status Date           object
# Agency                object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['Published Date'])

# %%
df.columns
# Out:
# Index(['Traffic Report ID', 'Published Date', 'Issue Reported', 'Location',
#        'Latitude', 'Longitude', 'Address', 'Status', 'Status Date', 'Agency',
#        'date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Traffic Report ID                 object
# Published Date                    object
# Issue Reported                    object
# Location                          object
# Latitude                         float64
# Longitude                        float64
# Address                           object
# Status                            object
# Status Date                       object
# Agency                            object
# date                 datetime64[ns, UTC]
# dtype: object

# %%
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#                                    Traffic Report ID  \
# 0  F350D780EA8AAA48030B4DB64F790C14DBCD757F_17096...
# 1  042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 2  BE73E73B642ECB6C6EDB4A52875A8017F69DFE5E_17080...
# 3  A5909010064EF753C5F090A07CFCDDFBF25E38F3_15865...
# 4  4A6C39763AD109EB75CE31C1EBFD53A0E883EE68_16543...
#
#                  Published Date     Issue Reported  \
# 0  03/06/2024 01:29:39 AM +0000    Stalled Vehicle
# 1  03/06/2024 01:26:42 AM +0000       Crash Urgent
# 2  02/15/2024 10:17:48 PM +0000    LOOSE LIVESTOCK
# 3  04/10/2020 09:31:11 PM +0000  TRFC HAZD/ DEBRIS
# 4  06/04/2022 05:51:05 PM +0000     Traffic Hazard
#
#                        Location   Latitude  Longitude  \
# 0   POINT (-97.705874 30.32358)  30.323580 -97.705874
# 1  POINT (-97.698567 30.342505)  30.342505 -97.698567
# 2    POINT (-97.717911 30.0578)  30.057800 -97.717911
# 3  POINT (-97.866676 30.140878)  30.140878 -97.866676
# 4  POINT (-97.825791 30.455444)  30.455444 -97.825791
#
#                                              Address    Status  \
# 0  E 290 Svrd Wb To Ih 35 Nb Ramp / N Ih 35 Svrd ...  ARCHIVED
# 1                               8024 N Ih 35 Svrd Sb  ARCHIVED
# 2                                     12400 Glass Rd  ARCHIVED
# 3  S Sh 45 W Eb & S Sh 45 W Eb To Bliss Spillar Ramp  ARCHIVED
# 4                     Anderson Mill Rd & N Fm 620 Rd  ARCHIVED
#
#                     Status Date                Agency  \
# 0  03/06/2024 02:10:12 AM +0000  AUSTIN PD
# 1  03/06/2024 02:45:13 AM +0000  AUSTIN PD
# 2  02/15/2024 11:33:08 PM +0000  TRAVIS COUNTY SHERIF
# 3  04/10/2020 09:55:03 PM +0000                   NaN
# 4  06/04/2022 06:20:03 PM +0000                   NaN
#
#                        date  year
# 0 2024-03-06 01:29:39+00:00  2024
# 1 2024-03-06 01:26:42+00:00  2024
# 2 2024-02-15 22:17:48+00:00  2024
# 3 2020-04-10 21:31:11+00:00  2020
# 4 2022-06-04 17:51:05+00:00  2022

# %%
len(df[(df['Issue Reported'] == 'Traffic Hazard') & (df['year'] == 2023)])
# Out:
# 14061

# %%
df[(df['Issue Reported'] == 'Traffic Hazard') & (df['year'] == 2024)].shape[0]
# Out:
# 12644

# %%
def square(x):
  return x*x

# %%
a = square(2)

# %%
print (a)
# Out:
# 4

# %%
a = lambda x: x*x

# %%
print (a(5))
# Out:
# 25

# %%
print (a(25))
# Out:
# 625

# %%
df['Issue Lower'] = df['Issue Reported'].apply
(lambda x: x.lower() if pd.notnull(x) else x)
# Out:
# <function __main__.<lambda>(x)>

# %%
df.columns
# Out:
# Index(['Traffic Report ID', 'Published Date', 'Issue Reported', 'Location',
#        'Latitude', 'Longitude', 'Address', 'Status', 'Status Date', 'Agency',
#        'date', 'year', 'Issue Lower'],
#       dtype='object')

# %%
df.head()
# Out:
#                                    Traffic Report ID  \
# 0  F350D780EA8AAA48030B4DB64F790C14DBCD757F_17096...
# 1  042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 2  BE73E73B642ECB6C6EDB4A52875A8017F69DFE5E_17080...
# 3  A5909010064EF753C5F090A07CFCDDFBF25E38F3_15865...
# 4  4A6C39763AD109EB75CE31C1EBFD53A0E883EE68_16543...
#
#                  Published Date     Issue Reported  \
# 0  03/06/2024 01:29:39 AM +0000    Stalled Vehicle
# 1  03/06/2024 01:26:42 AM +0000       Crash Urgent
# 2  02/15/2024 10:17:48 PM +0000    LOOSE LIVESTOCK
# 3  04/10/2020 09:31:11 PM +0000  TRFC HAZD/ DEBRIS
# 4  06/04/2022 05:51:05 PM +0000     Traffic Hazard
#
#                        Location   Latitude  Longitude  \
# 0   POINT (-97.705874 30.32358)  30.323580 -97.705874
# 1  POINT (-97.698567 30.342505)  30.342505 -97.698567
# 2    POINT (-97.717911 30.0578)  30.057800 -97.717911
# 3  POINT (-97.866676 30.140878)  30.140878 -97.866676
# 4  POINT (-97.825791 30.455444)  30.455444 -97.825791
#
#                                              Address    Status  \
# 0  E 290 Svrd Wb To Ih 35 Nb Ramp / N Ih 35 Svrd ...  ARCHIVED
# 1                               8024 N Ih 35 Svrd Sb  ARCHIVED
# 2                                     12400 Glass Rd  ARCHIVED
# 3  S Sh 45 W Eb & S Sh 45 W Eb To Bliss Spillar Ramp  ARCHIVED
# 4                     Anderson Mill Rd & N Fm 620 Rd  ARCHIVED
#
#                     Status Date                Agency  \
# 0  03/06/2024 02:10:12 AM +0000  AUSTIN PD
# 1  03/06/2024 02:45:13 AM +0000  AUSTIN PD
# 2  02/15/2024 11:33:08 PM +0000  TRAVIS COUNTY SHERIF
# 3  04/10/2020 09:55:03 PM +0000                   NaN
# 4  06/04/2022 06:20:03 PM +0000                   NaN
#
#                        date  year  \
# 0 2024-03-06 01:29:39+00:00  2024
# 1 2024-03-06 01:26:42+00:00  2024
# 2 2024-02-15 22:17:48+00:00  2024
# 3 2020-04-10 21:31:11+00:00  2020
# 4 2022-06-04 17:51:05+00:00  2022
#
#                                          Issue Lower
# 0  <bound method Series.apply of 0           Stal...
# 1  <bound method Series.apply of 0           Stal...
# 2  <bound method Series.apply of 0           Stal...
# 3  <bound method Series.apply of 0           Stal...
# 4  <bound method Series.apply of 0           Stal...

# %%
df.dtypes
# Out:
# Traffic Report ID                 object
# Published Date                    object
# Issue Reported                    object
# Location                          object
# Latitude                         float64
# Longitude                        float64
# Address                           object
# Status                            object
# Status Date                       object
# Agency                            object
# date                 datetime64[ns, UTC]
# year                               int32
# Issue Lower                       object
# dtype: object

# %%
df['Issue Reported'] = df['Issue Reported'].astype('string')

# %%
df.dtypes
# Out:
# Traffic Report ID                 object
# Published Date                    object
# Issue Reported            string[python]
# Location                          object
# Latitude                         float64
# Longitude                        float64
# Address                           object
# Status                            object
# Status Date                       object
# Agency                            object
# date                 datetime64[ns, UTC]
# year                               int32
# Issue Lower                       object
# dtype: object

# %%
df['Issue Lower'] = df['Issue Reported'].apply
(lambda x: x.lower() if pd.notnull(x) else x)
# Out:
# <function __main__.<lambda>(x)>

# %%
df.dtypes
# Out:
# Traffic Report ID                 object
# Published Date                    object
# Issue Reported            string[python]
# Location                          object
# Latitude                         float64
# Longitude                        float64
# Address                           object
# Status                            object
# Status Date                       object
# Agency                            object
# date                 datetime64[ns, UTC]
# year                               int32
# Issue Lower                       object
# dtype: object

# %%
df.head()
# Out:
#                                    Traffic Report ID  \
# 0  F350D780EA8AAA48030B4DB64F790C14DBCD757F_17096...
# 1  042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 2  BE73E73B642ECB6C6EDB4A52875A8017F69DFE5E_17080...
# 3  A5909010064EF753C5F090A07CFCDDFBF25E38F3_15865...
# 4  4A6C39763AD109EB75CE31C1EBFD53A0E883EE68_16543...
#
#                  Published Date     Issue Reported  \
# 0  03/06/2024 01:29:39 AM +0000    Stalled Vehicle
# 1  03/06/2024 01:26:42 AM +0000       Crash Urgent
# 2  02/15/2024 10:17:48 PM +0000    LOOSE LIVESTOCK
# 3  04/10/2020 09:31:11 PM +0000  TRFC HAZD/ DEBRIS
# 4  06/04/2022 05:51:05 PM +0000     Traffic Hazard
#
#                        Location   Latitude  Longitude  \
# 0   POINT (-97.705874 30.32358)  30.323580 -97.705874
# 1  POINT (-97.698567 30.342505)  30.342505 -97.698567
# 2    POINT (-97.717911 30.0578)  30.057800 -97.717911
# 3  POINT (-97.866676 30.140878)  30.140878 -97.866676
# 4  POINT (-97.825791 30.455444)  30.455444 -97.825791
#
#                                              Address    Status  \
# 0  E 290 Svrd Wb To Ih 35 Nb Ramp / N Ih 35 Svrd ...  ARCHIVED
# 1                               8024 N Ih 35 Svrd Sb  ARCHIVED
# 2                                     12400 Glass Rd  ARCHIVED
# 3  S Sh 45 W Eb & S Sh 45 W Eb To Bliss Spillar Ramp  ARCHIVED
# 4                     Anderson Mill Rd & N Fm 620 Rd  ARCHIVED
#
#                     Status Date                Agency  \
# 0  03/06/2024 02:10:12 AM +0000  AUSTIN PD
# 1  03/06/2024 02:45:13 AM +0000  AUSTIN PD
# 2  02/15/2024 11:33:08 PM +0000  TRAVIS COUNTY SHERIF
# 3  04/10/2020 09:55:03 PM +0000                   NaN
# 4  06/04/2022 06:20:03 PM +0000                   NaN
#
#                        date  year  \
# 0 2024-03-06 01:29:39+00:00  2024
# 1 2024-03-06 01:26:42+00:00  2024
# 2 2024-02-15 22:17:48+00:00  2024
# 3 2020-04-10 21:31:11+00:00  2020
# 4 2022-06-04 17:51:05+00:00  2022
#
#                                          Issue Lower
# 0  <bound method Series.apply of 0           Stal...
# 1  <bound method Series.apply of 0           Stal...
# 2  <bound method Series.apply of 0           Stal...
# 3  <bound method Series.apply of 0           Stal...
# 4  <bound method Series.apply of 0           Stal...

# %%
print (df['Issue Reported'])
# Out:
# 0           Stalled Vehicle
# 1              Crash Urgent
# 2           LOOSE LIVESTOCK
# 3         TRFC HAZD/ DEBRIS
# 4            Traffic Hazard
#                 ...
# 425636        Crash Service
# 425637       Traffic Hazard
# 425638       Traffic Hazard
# 425639        Crash Service
# 425640       Traffic Hazard
# Name: Issue Reported, Length: 425641, dtype: string

# %%
print (df['Issue Reported'])
# Out:
# 0           Stalled Vehicle
# 1              Crash Urgent
# 2           LOOSE LIVESTOCK
# 3         TRFC HAZD/ DEBRIS
# 4            Traffic Hazard
#                 ...
# 425636        Crash Service
# 425637       Traffic Hazard
# 425638       Traffic Hazard
# 425639        Crash Service
# 425640       Traffic Hazard
# Name: Issue Reported, Length: 425641, dtype: string

# %%
print (name)
# Out:
# Charlie

# %%
print (name.lower())
# Out:
# charlie

# %%
print (df['Issue Reported'].str.lower())
# Out:
# 0           stalled vehicle
# 1              crash urgent
# 2           loose livestock
# 3         trfc hazd/ debris
# 4            traffic hazard
#                 ...
# 425636        crash service
# 425637       traffic hazard
# 425638       traffic hazard
# 425639        crash service
# 425640       traffic hazard
# Name: Issue Reported, Length: 425641, dtype: string

# %%
df['Issue Lower'] = df['Issue Reported'].apply(lambda x:x.lower())

# %%
df.head()
# Out:
#                                    Traffic Report ID  \
# 0  F350D780EA8AAA48030B4DB64F790C14DBCD757F_17096...
# 1  042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 2  BE73E73B642ECB6C6EDB4A52875A8017F69DFE5E_17080...
# 3  A5909010064EF753C5F090A07CFCDDFBF25E38F3_15865...
# 4  4A6C39763AD109EB75CE31C1EBFD53A0E883EE68_16543...
#
#                  Published Date     Issue Reported  \
# 0  03/06/2024 01:29:39 AM +0000    Stalled Vehicle
# 1  03/06/2024 01:26:42 AM +0000       Crash Urgent
# 2  02/15/2024 10:17:48 PM +0000    LOOSE LIVESTOCK
# 3  04/10/2020 09:31:11 PM +0000  TRFC HAZD/ DEBRIS
# 4  06/04/2022 05:51:05 PM +0000     Traffic Hazard
#
#                        Location   Latitude  Longitude  \
# 0   POINT (-97.705874 30.32358)  30.323580 -97.705874
# 1  POINT (-97.698567 30.342505)  30.342505 -97.698567
# 2    POINT (-97.717911 30.0578)  30.057800 -97.717911
# 3  POINT (-97.866676 30.140878)  30.140878 -97.866676
# 4  POINT (-97.825791 30.455444)  30.455444 -97.825791
#
#                                              Address    Status  \
# 0  E 290 Svrd Wb To Ih 35 Nb Ramp / N Ih 35 Svrd ...  ARCHIVED
# 1                               8024 N Ih 35 Svrd Sb  ARCHIVED
# 2                                     12400 Glass Rd  ARCHIVED
# 3  S Sh 45 W Eb & S Sh 45 W Eb To Bliss Spillar Ramp  ARCHIVED
# 4                     Anderson Mill Rd & N Fm 620 Rd  ARCHIVED
#
#                     Status Date                Agency  \
# 0  03/06/2024 02:10:12 AM +0000  AUSTIN PD
# 1  03/06/2024 02:45:13 AM +0000  AUSTIN PD
# 2  02/15/2024 11:33:08 PM +0000  TRAVIS COUNTY SHERIF
# 3  04/10/2020 09:55:03 PM +0000                   NaN
# 4  06/04/2022 06:20:03 PM +0000                   NaN
#
#                        date  year        Issue Lower
# 0 2024-03-06 01:29:39+00:00  2024    stalled vehicle
# 1 2024-03-06 01:26:42+00:00  2024       crash urgent
# 2 2024-02-15 22:17:48+00:00  2024    loose livestock
# 3 2020-04-10 21:31:11+00:00  2020  trfc hazd/ debris
# 4 2022-06-04 17:51:05+00:00  2022     traffic hazard

# %%
df['Issue Lower'] = df['Issue Reported'].apply(lambda x: x.lower() if isinstance(x, str) else x)

# %%
df.groupby('Issue Reported').size().sort_values(ascending=False).head(10)
# Out:
# Issue Reported
# Traffic Hazard           125951
# Crash Urgent             103763
# Crash Service             58457
# COLLISION                 44029
# TRFC HAZD/ DEBRIS         32653
# LOOSE LIVESTOCK           11481
# COLLISION WITH INJURY     11232
# Stalled Vehicle            9224
# zSTALLED VEHICLE           8930
# COLLISN/ LVNG SCN          8517
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Published Date'])
df['Month'] = df['Date'].dt.month
monthly_counts = df.groupby('Month').size()

# %%
print (monthly_counts)
# Out:
# Month
# 1     32557
# 2     35017
# 3     36859
# 4     35927
# 5     39608
# 6     33879
# 7     31769
# 8     33867
# 9     33463
# 10    40286
# 11    37173
# 12    35236
# dtype: int64

# %%
df.groupby('Issue Reported')['Traffic Report ID'].count()
# Out:
# Issue Reported
# AUTO/ PED                        180
# BLOCKED DRIV/ HWY                938
# BOAT ACCIDENT                    136
# COLLISION                      44029
# COLLISION WITH INJURY          11232
# COLLISION/PRIVATE PROPERTY      1886
# COLLISN / FTSRA                    1
# COLLISN/ LVNG SCN               8517
# Crash Service                  58457
# Crash Urgent                  103763
# FLEET ACC/ FATAL                   3
# FLEET ACC/ INJURY                 61
# HIGH WATER                         6
# ICY ROADWAY                       78
# LOOSE LIVESTOCK                11481
# N / HZRD TRFC VIOL                13
# OBSTRUCT HWY                      15
# Stalled Vehicle                 9224
# TRAFFIC FATALITY                 128
# TRFC HAZD/ DEBRIS              32653
# Traffic Hazard                125951
# Traffic Impediment              6255
# VEHICLE FIRE                    1704
# zSTALLED VEHICLE                8930
# Name: Traffic Report ID, dtype: int64

# %%
df.sort_values(by='Published Date', ascending=False).head()
# Out:
#                                         Traffic Report ID  \
# 407838  D0A54D25D6D76D15DAA175979EDA75CD9FD411B3_17356...
# 407837  78AE9F6E6A12A1AF3C5A87F0F649F73AA2B4C7BE_17356...
# 407883  9D758147F7E39A4CB91081AB512FEC6385AA6E80_17356...
# 407842  88308D640F3031B16B0E9C4663716C0CB7169E50_17356...
# 407824  08BABBA456D31986A0E6B7A77F63A6D11CC82FC3_17356...
#
#                       Published Date     Issue Reported  \
# 407838  12/31/2024 12:59:27 AM +0000     Traffic Hazard
# 407837  12/31/2024 12:56:51 AM +0000     Traffic Hazard
# 407883  12/31/2024 12:56:10 PM +0000          COLLISION
# 407842  12/31/2024 12:54:46 AM +0000       Crash Urgent
# 407824  12/31/2024 12:52:00 AM +0000  TRFC HAZD/ DEBRIS
#
#                             Location   Latitude  Longitude  \
# 407838  POINT (-97.771507 30.360904)  30.360904 -97.771507
# 407837                           NaN   0.000000   0.000000
# 407883  POINT (-97.861719 30.318203)  30.318203 -97.861719
# 407842    POINT (-97.6026 30.336842)  30.336842 -97.602600
# 407824  POINT (-97.641064 30.156156)  30.156156 -97.641064
#
#                                Address    Status  \
# 407838  Far West Blvd / North Hills Dr  ARCHIVED
# 407837                  2121 ALLANDALE  ARCHIVED
# 407883        FM 2244 RD / S MARLY WAY  ARCHIVED
# 407842         8011-8217 BLUE GOOSE RD  ARCHIVED
# 407824              ROSS RD / ELROY RD  ARCHIVED
#
#                          Status Date                Agency  \
# 407838  12/31/2024 01:05:15 AM +0000  AUSTIN PD
# 407837  12/31/2024 01:05:15 AM +0000  AUSTIN PD
# 407883  12/31/2024 01:15:18 PM +0000  TRAVIS COUNTY SHERIF
# 407842  12/31/2024 01:30:17 AM +0000  AUSTIN PD
# 407824  12/31/2024 01:00:18 AM +0000  TRAVIS COUNTY SHERIF
#
#                             date  year        Issue Lower  Hour  Rush Hour  \
# 407838 2024-12-31 00:59:27+00:00  2024     traffic hazard     0      False
# 407837 2024-12-31 00:56:51+00:00  2024     traffic hazard     0      False
# 407883 2024-12-31 12:56:10+00:00  2024          collision    12      False
# 407842 2024-12-31 00:54:46+00:00  2024       crash urgent     0      False
# 407824 2024-12-31 00:52:00+00:00  2024  trfc hazd/ debris     0      False
#
#                             Date  Month
# 407838 2024-12-31 00:59:27+00:00     12
# 407837 2024-12-31 00:56:51+00:00     12
# 407883 2024-12-31 12:56:10+00:00     12
# 407842 2024-12-31 00:54:46+00:00     12
# 407824 2024-12-31 00:52:00+00:00     12

# %%
crash_urgent = df[df['Issue Reported'] == 'Crash Urgent']
crash_urgent.groupby('Month').size().sort_values(ascending=False)
# Out:
# Month
# 10    10059
# 11     9408
# 5      9334
# 3      9063
# 12     9026
# 4      8652
# 2      8615
# 1      8310
# 6      7982
# 9      7980
# 8      7822
# 7      7512
# dtype: int64

# %%
looselivestock = df[df['Issue Reported'] == 'LOOSE LIVESTOCK']
looselivestock.groupby('Month').size().sort_values(ascending=False)
# Out:
# Month
# 9     1132
# 5     1088
# 10    1066
# 7     1019
# 11    1012
# 8     1007
# 3      921
# 6      875
# 4      871
# 12     841
# 1      827
# 2      822
# dtype: int64
